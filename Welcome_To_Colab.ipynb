# %% [markdown]
# <a href="https://colab.research.google.com/github/Anvay-io/College_Club_Website/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Axha  Axha")
# Out:
# Axha  Axha
